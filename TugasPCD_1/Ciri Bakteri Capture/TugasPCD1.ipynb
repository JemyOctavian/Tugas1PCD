# %%
#import library opencv
import cv2
import matplotlib
import numpy as np

#membaca gambar
img = cv2.imread('Tugas1.jpg')


cv2.imshow('Capture',img)
cv2.waitKey(0)
cv2.destroyAllwindows()

# %%
# konversi ke grayscale
gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

#grayscale image represented as a 2-d array
print(gray_img)
# Out:
# [[168 168 168 ... 180 176 176]
#  [168 168 168 ... 179 177 177]
#  [168 168 168 ... 177 180 180]
#  ...
#  [ 85  92 105 ...  36  32  21]
#  [ 68  75  87 ...  37  16  13]
#  [ 59  66  78 ...  28  12   9]]

# %%
#Konversi gambar ke RGB warna untuk matplotlib
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#menampilkan gambar with matplotlib
plt.imshow(img)
